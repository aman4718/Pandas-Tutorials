# %%
import pandas as pd

# %%
df_d = pd.read_excel('D:\Ineuron\Data\Attribute DataSet.xlsx')

# %%
df_d
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#read data from another sheet
pd.read_excel('D:\Ineuron\Data\Attribute DataSet.xlsx',sheet_name = 'Sheet2',header=None)
# Out:
#         0       1
# 0   fgfdg     NaN
# 1    gdfg     NaN
# 2  dfgfdg  dfgdfg
# 3    gdfg  dfgdfg
# 4  dfgdfg     fdg
# 5     dfg  dfgdfg
# 6     dfg     NaN

# %%
#by default 5 records 
df.head(1)
# Out:
#      Dress_ID Style Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852  Sexy   Low     4.6    M  Summer   o-neck    sleevless
#
#   waiseline Material FabricType Decoration Pattern Type  Recommendation
# 0    empire      NaN    chiffon    ruffles       animal               1

# %%
#by default 5 records 
df.tail(2)
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline Material  FabricType Decoration Pattern Type  Recommendation
# 498    empire     silk  broadcloth   applique        print               1
# 499    empire   cotton    Corduroy       lace        solid               0

# %%
df =pd.read_csv('haberman.csv')

# %%
df
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
# sep the data
df =pd.read_csv('haberman1.csv',sep='@')

# %%
df
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
## read git hub data
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Smarket.csv')
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction
# 0     2001  0.381 -0.192 -2.624 -1.055  5.010  1.19130  0.959        Up
# 1     2001  0.959  0.381 -0.192 -2.624 -1.055  1.29650  1.032        Up
# 2     2001  1.032  0.959  0.381 -0.192 -2.624  1.41120 -0.623      Down
# 3     2001 -0.623  1.032  0.959  0.381 -0.192  1.27600  0.614        Up
# 4     2001  0.614 -0.623  1.032  0.959  0.381  1.20570  0.213        Up
# ...    ...    ...    ...    ...    ...    ...      ...    ...       ...
# 1245  2005  0.422  0.252 -0.024 -0.584 -0.285  1.88850  0.043        Up
# 1246  2005  0.043  0.422  0.252 -0.024 -0.584  1.28581 -0.955      Down
# 1247  2005 -0.955  0.043  0.422  0.252 -0.024  1.54047  0.130        Up
# 1248  2005  0.130 -0.955  0.043  0.422  0.252  1.42236 -0.298      Down
# 1249  2005 -0.298  0.130 -0.955  0.043  0.422  1.38254 -0.489      Down
#
# [1250 rows x 9 columns]

# %%
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BCF.csv')
# Out:
#            date  values.I2P  values.P2I  values.JPI
# 0    1996-04-01   -2.580556   -0.836444        63.3
# 1    1996-05-01   -2.882258   -1.972581        66.3
# 2    1996-06-01   -1.742778   -0.478778        59.7
# 3    1996-07-01   -0.397796   -1.574301        63.3
# 4    1996-08-01   -0.977151   -1.797312        63.8
# ..          ...         ...         ...         ...
# 112  2005-08-01   -2.144935   -1.646989        49.0
# 113  2005-09-01   -3.543270   -1.769889        49.9
# 114  2005-10-01   -4.500484   -2.309946        50.6
# 115  2005-11-01   -4.098556   -1.528611        57.4
# 116  2005-12-01   -5.797043   -2.872849        52.9
#
# [117 rows x 4 columns]

# %%
#read html
pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
js = pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'draft', 'pull_request', 'body', 'reactions',
#        'timeline_url', 'performed_via_github_app', 'state_reason'],
#       dtype='object')

# %%
js['user']
# Out:
# 0     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 1     {'login': 'shourya5', 'id': 73142986, 'node_id...
# 2     {'login': 'adrienpacifico', 'id': 6614121, 'no...
# 3     {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 4     {'login': 'attack68', 'id': 24256554, 'node_id...
# 5     {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 6     {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 7     {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 8     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 9     {'login': 'GivyBoy', 'id': 58392771, 'node_id'...
# 10    {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 11    {'login': 'SomtochiUmeh', 'id': 74836691, 'nod...
# 12    {'login': 'adrienpacifico', 'id': 6614121, 'no...
# 13    {'login': 'Brinkhuis', 'id': 3044985, 'node_id...
# 14    {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 15    {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 16    {'login': 'parthi-siva', 'id': 25401444, 'node...
# ...

# %%
js['user'][0]
# Out:
# {'login': 'jbrockmendel',
#  'id': 8078968,
#  'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/jbrockmendel',
#  'html_url': 'https://github.com/jbrockmendel',
#  'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#  'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#  'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#  'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#  'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
# ...

# %%
df_d.to_json('test.json')

# %%
pwd
# Out:
# 'C:\\Users\\Kumar Aman'

# %%
df_d.to_csv("D:\\Ineuron\\Data\\test1.csv")

# %%
df_d.to_csv("D:\\Ineuron\\Data\\test2.csv",sep="#")

# %%
df_d.to_csv("D:\\Ineuron\\Data\\test3.csv",index=False)

# %% [raw]
# Mysql :
#
#     1. Create a  table attribute dataset and dress dataset
#     2. Do a bulk load for these two table for respective dataset
#     3. read these dataset in pandas as a dataframe
#     4. Convert attribute dataset in json format
#     5. Store this dataset into mongodb
#     6. in sql task try to perform left join operation with attrubute dataset and dress dataset on column Dress_ID
#     7. Write a sql query to find out how many unique dress that we have based on dress id
#     8. Try to find out how mnay dress is having recommendation 0
#     9. Try to find out total dress sell for individual dress id
#     10. Try to find out a third highest most selling dress id

# %%
### 30 July CLass

# %%
import pandas as pd

# %%
df = pd.read_csv('sales_data_final.csv')

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
type(df['order_date'])
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df[['profit','year']]
# Out:
#          profit  year
# 0      106.1400  2011
# 1       36.0360  2011
# 2       29.6400  2011
# 3      -26.0550  2011
# 4       37.7700  2011
# ...         ...   ...
# 51285    4.5188  2014
# 51286    0.4200  2014
# 51287   12.3600  2014
# 51288    0.5600  2014
# 51289   -0.6048  2014
#
# [51290 rows x 2 columns]

# %%
df[['profit']]
# Out:
#          profit
# 0      106.1400
# 1       36.0360
# 2       29.6400
# 3      -26.0550
# 4       37.7700
# ...         ...
# 51285    4.5188
# 51286    0.4200
# 51287   12.3600
# 51288    0.5600
# 51289   -0.6048
#
# [51290 rows x 1 columns]

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
df.dtypes[df.dtypes=='object']
# Out:
# order_id          object
# order_date        object
# ship_date         object
# ship_mode         object
# customer_name     object
# segment           object
# state             object
# country           object
# market            object
# region            object
# product_id        object
# category          object
# sub_category      object
# product_name      object
# sales             object
# order_priority    object
# dtype: object

# %%
df.dtypes[df.dtypes=='object'].index
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'order_priority'],
#       dtype='object')

# %%
df[df.dtypes[df.dtypes=='object'].index]
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df[df.dtypes[df.dtypes=='object'].index].describe()
# Out:
#               order_id order_date   ship_date       ship_mode  \
# count            51290      51290       51290           51290
# unique           25035       1430        1464               4
# top     CA-2014-100111  6/18/2014  11/22/2014  Standard Class
# freq                14        135         130           30775
#
#           customer_name   segment       state        country market   region  \
# count             51290     51290       51290          51290  51290    51290
# unique              795         3        1094            147      7       13
# top     Muhammed Yedwab  Consumer  California  United States   APAC  Central
# freq                108     26518        2001           9994  11002    11117
#
#              product_id         category sub_category product_name  sales  \
# count             51290            51290        51290        51290  51290
# unique            10292                3           17         3788   2246
# ...

# %%
df.dtypes[df.dtypes=='float'].index
# Out:
# Index(['discount', 'profit', 'shipping_cost'], dtype='object')

# %%
df[df.dtypes[df.dtypes=='float'].index]
# Out:
#        discount    profit  shipping_cost
# 0           0.0  106.1400          35.46
# 1           0.1   36.0360           9.72
# 2           0.0   29.6400           8.17
# 3           0.5  -26.0550           4.82
# 4           0.1   37.7700           4.70
# ...         ...       ...            ...
# 51285       0.2    4.5188           0.89
# 51286       0.0    0.4200           0.49
# 51287       0.0   12.3600           0.35
# 51288       0.0    0.5600           0.20
# 51289       0.2   -0.6048           0.17
#
# [51290 rows x 3 columns]

# %%
df.order_id
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
#               ...
# 51285     CA-2014-115427
# 51286       MO-2014-2560
# 51287     MX-2014-110527
# 51288     MX-2014-114783
# 51289     CA-2014-156720
# Name: order_id, Length: 51290, dtype: object

# %%
df.order_id[1:4]
# Out:
# 1      IN-2011-47883
# 2       HU-2011-1220
# 3    IT-2011-3647632
# Name: order_id, dtype: object

# %%
df.order_id[1:40:2]
# Out:
# 1       IN-2011-47883
# 3     IT-2011-3647632
# 5       IN-2011-47883
# 7       IN-2011-79397
# 9        IZ-2011-4680
# 11      IN-2011-65159
# 13      IN-2011-33652
# 15     MX-2011-160234
# 17      ID-2011-80230
# 19      ID-2011-12596
# 21       IR-2011-7690
# 23       TZ-2011-7370
# 25      IN-2011-65159
# 27     MX-2011-111255
# 29     MX-2011-158771
# 31     MX-2011-111255
# 33     US-2011-136007
# 35     MX-2011-159373
# 37    IT-2011-2942451
# 39      IN-2011-33036
# Name: order_id, dtype: object

# %%
df['category']
# Out:
# 0        Office Supplies
# 1        Office Supplies
# 2        Office Supplies
# 3        Office Supplies
# 4              Furniture
#               ...
# 51285    Office Supplies
# 51286    Office Supplies
# 51287    Office Supplies
# 51288    Office Supplies
# 51289    Office Supplies
# Name: category, Length: 51290, dtype: object

# %%
df['category1'] = 'sudh'

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1'],
#       dtype='object')

# %%
df['order_id'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: order_id, Length: 51290, dtype: bool

# %%
df1 = pd.read_csv('DressSales.csv')

# %%
df1
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2/9/2013  4/9/2013  6/9/2013  8/9/2013  \
# 0    1006032852       2114       2274      2491      2660      2727      2887
# 1    1212192089        151        275       570       750       813      1066
# 2    1190380701          6          7         7         7         8         8
# 3     966005983       1005       1128      1326      1455      1507      1621
# 4     876339541        996       1175      1304      1396      1432      1559
# ..          ...        ...        ...       ...       ...       ...       ...
# 495   713391965          0          0         0       560       554       544
# 496   722565148          0          0         0       875       866       861
# 497   532874347          0          0         0       734       728       726
# 498   655464934          0          0         0       254       259       261
# 499   919930954          0          0         0       538       545       558
#
# ...

# %%
df1.columns
# Out:
# Index(['Dress_ID', '29/8/2013', '31/8/2013', '2/9/2013', '4/9/2013',
#        '6/9/2013', '8/9/2013', '10/9/2013', '12/9/2013', '14/9/2013',
#        '16/9/2013', '18/9/2013', '20/9/2013', '22/9/2013', '24/9/2013',
#        '26/9/2013', '28/9/2013', '30/9/2013', '2/10/2013', '4/10/2013',
#        '6/10/2013', '8/10/2010', '10/10/2013', '12/10/2013', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35'],
#       dtype='object')

# %%
df1['Unnamed: 26']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 495   NaN
# 496   NaN
# 497   NaN
# 498   NaN
# 499   NaN
# Name: Unnamed: 26, Length: 500, dtype: float64

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df['customer_name'].max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0         Toby Braunhardt
# 1             Joseph Holt
# 2           Annie Thurman
# 3            Eugene Moren
# 4             Joseph Holt
#                ...
# 51285          Erica Bern
# 51286           Liz Preis
# 51287    Charlotte Melton
# 51288       Tamara Dahlen
# 51289       Jill Matthias
# Name: customer_name, Length: 51290, dtype: object>

# %%
df['profit']==max(df['profit'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: profit, Length: 51290, dtype: bool

# %%
df[df['profit']==max(df['profit'])]
# Out:
#              order_id order_date   ship_date       ship_mode customer_name  \
# 29530  CA-2013-118689  10/3/2013  10/10/2013  Standard Class  Tamara Chand
#
#          segment    state        country market   region  ...    category  \
# 29530  Corporate  Indiana  United States     US  Central  ...  Technology
#
#       sub_category                           product_name   sales quantity  \
# 29530      Copiers  Canon imageCLASS 2200 Advanced Copier  17,500        5
#
#        discount    profit  shipping_cost  order_priority  year
# 29530       0.0  8399.976         349.07          Medium  2013
#
# [1 rows x 21 columns]

# %%
df[df['profit']==max(df['profit'])]['customer_name']
# Out:
# 29530    Tamara Chand
# Name: customer_name, dtype: object

# %%
df['country']
# Out:
# 0              Algeria
# 1            Australia
# 2              Hungary
# 3               Sweden
# 4            Australia
#              ...
# 51285    United States
# 51286          Morocco
# 51287        Nicaragua
# 51288           Mexico
# 51289    United States
# Name: country, Length: 51290, dtype: object

# %%
df['country'] == 'Sweden'
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: country, Length: 51290, dtype: bool

# %%
df[df['country'] == 'Sweden']
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 3      IT-2011-3647632    1/1/2011    1/5/2011    Second Class
# 168    IT-2011-5951216   1/13/2011   1/20/2011  Standard Class
# 477    IT-2011-5645183    2/3/2011    2/5/2011    Second Class
# 1342   IT-2011-5233011   3/31/2011    4/6/2011  Standard Class
# 1554   IT-2011-2419493   4/12/2011   4/13/2011     First Class
# ...                ...         ...         ...             ...
# 50948  IT-2014-5217096  12/26/2014  12/31/2014  Standard Class
# 50949  IT-2014-5217096  12/26/2014  12/31/2014  Standard Class
# 50972  IT-2014-4046179  12/27/2014  12/30/2014    Second Class
# 51086  IT-2014-2362249  12/29/2014    1/1/2015     First Class
# 51121  IT-2014-2362249  12/29/2014    1/1/2015     First Class
#
#          customer_name      segment            state country market region  \
# 3         Eugene Moren  Home Office        Stockholm  Sweden     EU  North
# ...

# %%
len(df[df['country'] == 'Sweden'])
# Out:
# 203

# %%
df['shipping_cost'] > 20
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: shipping_cost, Length: 51290, dtype: bool

# %%
df[df['shipping_cost'] > 20]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011    1/6/2011  Standard Class
# 6         CA-2011-1510    1/2/2011    1/6/2011  Standard Class
# 7        IN-2011-79397    1/3/2011    1/3/2011        Same Day
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 9         IZ-2011-4680    1/3/2011    1/7/2011  Standard Class
# ...                ...         ...         ...             ...
# 51241  ES-2014-3638865  12/31/2014    1/1/2015     First Class
# 51242   MX-2014-141712  12/31/2014  12/31/2014        Same Day
# 51243    IN-2014-78627  12/31/2014    1/4/2015  Standard Class
# 51244  IT-2014-3715679  12/31/2014    1/5/2015    Second Class
# 51245    IN-2014-75603  12/31/2014    1/5/2015    Second Class
#
#           customer_name      segment            state         country  market  \
# 0       Toby Braunhardt     Consumer      Constantine         Algeria  Africa
# ...

# %%
df[df['shipping_cost'] > 80]
# Out:
#              order_id  order_date ship_date       ship_mode  \
# 7       IN-2011-79397    1/3/2011  1/3/2011        Same Day
# 8       ID-2011-80230    1/3/2011  1/9/2011  Standard Class
# 9        IZ-2011-4680    1/3/2011  1/7/2011  Standard Class
# 27     MX-2011-111255    1/4/2011  1/9/2011    Second Class
# 43     MX-2011-109267    1/5/2011  1/9/2011  Standard Class
# ...               ...         ...       ...             ...
# 51154   IN-2014-49206  12/30/2014  1/1/2015    Second Class
# 51228  MX-2014-116267  12/31/2014  1/3/2015    Second Class
# 51229   IN-2014-43550  12/31/2014  1/1/2015     First Class
# 51230    RS-2014-1460  12/31/2014  1/2/2015    Second Class
# 51231   IN-2014-30390  12/31/2014  1/3/2015     First Class
#
#              customer_name    segment            state      country market  \
# 7              Kean Nguyen  Corporate  New South Wales    Australia   APAC
# 8             Ken Lonsdale   Consumer         Auckland  New Zealand   APAC
# ...

# %%
df[df['shipping_cost'] > 80]['country']
# Out:
# 7          Australia
# 8        New Zealand
# 9               Iraq
# 27            Brazil
# 43            Mexico
#             ...
# 51154      Indonesia
# 51228         Brazil
# 51229      Indonesia
# 51230         Russia
# 51231       Thailand
# Name: country, Length: 3984, dtype: object

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df[(df['shipping_cost'] >100) &  (df['profit']<10)]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 257     MX-2011-146584   1/21/2011   1/27/2011  Standard Class
# 451    ES-2011-1640672    2/2/2011    2/5/2011     First Class
# 625      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# 626      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# ...                ...         ...         ...             ...
# 50781   CA-2014-147956  12/25/2014    1/1/2015  Standard Class
# 50969   US-2014-120166  12/27/2014  12/31/2014  Standard Class
# 50970  ES-2014-4296634  12/27/2014    1/2/2015  Standard Class
# 51034    ID-2014-68183  12/29/2014  12/31/2014     First Class
# 51153    ID-2014-51509  12/30/2014    1/1/2015    Second Class
#
#               customer_name    segment                         state  \
# 8              Ken Lonsdale   Consumer                      Auckland
# ...

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df[df['order_date'].str.contains('2011', na=False)]
# Out:
#              order_id  order_date ship_date       ship_mode     customer_name  \
# 0        AG-2011-2040    1/1/2011  1/6/2011  Standard Class   Toby Braunhardt
# 1       IN-2011-47883    1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 2        HU-2011-1220    1/1/2011  1/5/2011    Second Class     Annie Thurman
# 3     IT-2011-3647632    1/1/2011  1/5/2011    Second Class      Eugene Moren
# 4       IN-2011-47883    1/1/2011  1/8/2011  Standard Class       Joseph Holt
# ...               ...         ...       ...             ...               ...
# 8993   CA-2011-133592  12/31/2011  1/7/2012  Standard Class  Katherine Murray
# 8994  ES-2011-1846006  12/31/2011  1/2/2012     First Class     Odella Nelson
# 8995   US-2011-143231  12/31/2011  1/3/2012     First Class      Gary Mitchum
# 8996   MX-2011-162789  12/31/2011  1/4/2012  Standard Class    Monica Federle
# 8997   CA-2011-157644  12/31/2011  1/1/2012     First Class     Aaron Hawkins
#
# ...

# %%
pd.to_datetime(df['order_date'])
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
#            ...
# 51285   2014-12-31
# 51286   2014-12-31
# 51287   2014-12-31
# 51288   2014-12-31
# 51289   2014-12-31
# Name: order_date, Length: 51290, dtype: datetime64[ns]

# %%
date = pd.to_datetime(df['order_date'])

# %%
date
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
#            ...
# 51285   2014-12-31
# 51286   2014-12-31
# 51287   2014-12-31
# 51288   2014-12-31
# 51289   2014-12-31
# Name: order_date, Length: 51290, dtype: datetime64[ns]

# %%
type(date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['converted_order_date'] = pd.to_datetime(df['order_date'])

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df['order_date_year'] = df['converted_order_date'].dt.year

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#                   product_name sales quantity discount   profit  \
# 0          Tenex Lockers, Blue   408        2      0.0  106.140
# ...

# %%
df['order_date_month'] = df['converted_order_date'].dt.month

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... sales  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...   408
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...   120
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...    66
# 3  Home Office        Stockholm     Sweden      EU    North  ...    45
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...   114
#
#   quantity discount   profit shipping_cost  order_priority  year  \
# ...

# %%
df['order_date_week'] = df['converted_order_date'].dt.week
# Out:
# <ipython-input-86-f16d57cd2fe8>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df['order_date_week'] = df['converted_order_date'].dt.week

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... quantity  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...        2
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...        3
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...        4
# 3  Home Office        Stockholm     Sweden      EU    North  ...        3
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...        5
#
#   discount   profit shipping_cost order_priority  year  converted_order_date  \
# ...

# %%
df[['converted_order_date','order_date_week']]
# Out:
#       converted_order_date  order_date_week
# 0               2011-01-01               52
# 1               2011-01-01               52
# 2               2011-01-01               52
# 3               2011-01-01               52
# 4               2011-01-01               52
# ...                    ...              ...
# 51285           2014-12-31                1
# 51286           2014-12-31                1
# 51287           2014-12-31                1
# 51288           2014-12-31                1
# 51289           2014-12-31                1
#
# [51290 rows x 2 columns]

# %%
df[df['order_date_year'] == 2014]
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 33759  ES-2014-2774938    1/1/2014  1/3/2014    Second Class
# 33760    IN-2014-47134    1/1/2014  1/5/2014  Standard Class
# 33761  IT-2014-4810734    1/1/2014  1/3/2014    Second Class
# 33762   US-2014-105830    1/1/2014  1/3/2014     First Class
# 33763   CA-2014-160395    1/1/2014  1/7/2014  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name    segment             state        country  market  \
# 33759       Fred Harton   Consumer     Ile-de-France         France      EU
# 33760       Kean Nguyen  Corporate          Victoria      Australia    APAC
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'converted_order_date', 'order_date_year', 'order_date_month',
#        'order_date_week'],
#       dtype='object')

# %%
df['order_date_month'].value_counts()
# Out:
# 11    6342
# 12    6302
# 9     5975
# 6     5331
# 8     5078
# 10    4490
# 5     3747
# 7     3166
# 4     3057
# 3     3035
# 1     2599
# 2     2168
# Name: order_date_month, dtype: int64

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... quantity  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...        2
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...        3
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...        4
# 3  Home Office        Stockholm     Sweden      EU    North  ...        3
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...        5
#
#   discount   profit shipping_cost order_priority  year  converted_order_date  \
# ...

# %%
###cost to company
df['cost_to_company'] = df['discount'] + df['shipping_cost']

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... discount  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      0.0
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      0.0
# 3  Home Office        Stockholm     Sweden      EU    North  ...      0.5
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
#
#     profit shipping_cost order_priority  year  converted_order_date  \
# ...

# %%
max(df['cost_to_company'])
# Out:
# 933.57

# %%
df[df['cost_to_company'] == max(df['cost_to_company'])]['product_name']
# Out:
# 13891    Plantronics CS510 - Over-the-Head monaural Wir...
# Name: product_name, dtype: object

# %%
df.drop('cost_to_company')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-101-01398d95bdca> in <module>
# ----> 1 df.drop('cost_to_company')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df.drop('cost_to_company',axis=1)
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... discount  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      0.0
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      0.0
# 3  Home Office        Stockholm     Sweden      EU    North  ...      0.5
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
#
#     profit shipping_cost order_priority  year  converted_order_date  \
# ...

# %%
df.drop('cost_to_company',axis=1,inplace=True)

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... quantity  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...        2
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...        3
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...        4
# 3  Home Office        Stockholm     Sweden      EU    North  ...        3
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...        5
#
#   discount   profit shipping_cost order_priority  year  converted_order_date  \
# ...

# %%
df.drop(1)
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.drop(1,inplace=True)

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 5    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... quantity  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...        2
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...        4
# 3  Home Office        Stockholm     Sweden      EU    North  ...        3
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...        5
# 5     Consumer  New South Wales  Australia    APAC  Oceania  ...        2
#
#   discount   profit shipping_cost order_priority  year  converted_order_date  \
# ...

# %%
### row operation in pandas loc,iloc

# %%
df.loc[[2,3]]
# Out:
#           order_id order_date ship_date     ship_mode  customer_name  \
# 2     HU-2011-1220   1/1/2011  1/5/2011  Second Class  Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011  Second Class   Eugene Moren
#
#        segment      state  country market region  ... quantity discount  \
# 2     Consumer   Budapest  Hungary   EMEA   EMEA  ...        4      0.0
# 3  Home Office  Stockholm   Sweden     EU  North  ...        3      0.5
#
#    profit shipping_cost order_priority  year  converted_order_date  \
# 2  29.640          8.17           High  2011            2011-01-01
# 3 -26.055          4.82           High  2011            2011-01-01
#
#    order_date_year  order_date_month order_date_week
# 2             2011                 1              52
# 3             2011                 1              52
#
# [2 rows x 25 columns]

# %%
df.loc[2:10]
# Out:
#            order_id order_date ship_date       ship_mode     customer_name  \
# 2      HU-2011-1220   1/1/2011  1/5/2011    Second Class     Annie Thurman
# 3   IT-2011-3647632   1/1/2011  1/5/2011    Second Class      Eugene Moren
# 4     IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 5     IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 6      CA-2011-1510   1/2/2011  1/6/2011  Standard Class   Magdelene Morse
# 7     IN-2011-79397   1/3/2011  1/3/2011        Same Day       Kean Nguyen
# 8     ID-2011-80230   1/3/2011  1/9/2011  Standard Class      Ken Lonsdale
# 9      IZ-2011-4680   1/3/2011  1/7/2011  Standard Class  Lindsay Williams
# 10    IN-2011-65159   1/3/2011  1/7/2011    Second Class      Larry Blacks
#
#         segment             state      country  market          region  ...  \
# 2      Consumer          Budapest      Hungary    EMEA            EMEA  ...
# ...

# %%
df.loc[2:10:2]
# Out:
#          order_id order_date ship_date       ship_mode    customer_name  \
# 2    HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 4   IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 6    CA-2011-1510   1/2/2011  1/6/2011  Standard Class  Magdelene Morse
# 8   ID-2011-80230   1/3/2011  1/9/2011  Standard Class     Ken Lonsdale
# 10  IN-2011-65159   1/3/2011  1/7/2011    Second Class     Larry Blacks
#
#      segment             state      country  market          region  ...  \
# 2   Consumer          Budapest      Hungary    EMEA            EMEA  ...
# 4   Consumer   New South Wales    Australia    APAC         Oceania  ...
# 6   Consumer           Ontario       Canada  Canada          Canada  ...
# 8   Consumer          Auckland  New Zealand    APAC         Oceania  ...
# 10  Consumer  National Capital  Philippines    APAC  Southeast Asia  ...
#
#    quantity discount    profit shipping_cost order_priority  year  \
# ...

# %%
df.loc[0:4,['order_id','order_date','ship_date']]
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040   1/1/2011  1/6/2011
# 2     HU-2011-1220   1/1/2011  1/5/2011
# 3  IT-2011-3647632   1/1/2011  1/5/2011
# 4    IN-2011-47883   1/1/2011  1/8/2011

# %%
df.iloc[0:4 , 0:3]
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040   1/1/2011  1/6/2011
# 2     HU-2011-1220   1/1/2011  1/5/2011
# 3  IT-2011-3647632   1/1/2011  1/5/2011
# 4    IN-2011-47883   1/1/2011  1/8/2011

# %% [markdown]
# loc - takes name indexes
# iloc - it understands internal index(i - default index)

# %%
df.iloc[2:6 , 3:6]
# Out:
#         ship_mode    customer_name      segment
# 3    Second Class     Eugene Moren  Home Office
# 4  Standard Class      Joseph Holt     Consumer
# 5  Standard Class      Joseph Holt     Consumer
# 6  Standard Class  Magdelene Morse     Consumer

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.dtypes
# Out:
# order_id                        object
# order_date                      object
# ship_date                       object
# ship_mode                       object
# customer_name                   object
# segment                         object
# state                           object
# country                         object
# market                          object
# region                          object
# product_id                      object
# category                        object
# sub_category                    object
# product_name                    object
# sales                           object
# quantity                         int64
# discount                       float64
# profit                         float64
# shipping_cost                  float64
# order_priority                  object
# year                             int64
# converted_order_date    datetime64[ns]
# order_date_year                  int64
# order_date_month                 int64
# ...

# %%
df.dtypes[(df.dtypes == 'float64') |(df.dtypes=='int64')].index
# Out:
# Index(['quantity', 'discount', 'profit', 'shipping_cost', 'year',
#        'order_date_year', 'order_date_month', 'order_date_week'],
#       dtype='object')

# %%
df[df.dtypes[(df.dtypes == 'float64') |(df.dtypes=='int64')].index]
# Out:
#        quantity  discount    profit  shipping_cost  year  order_date_year  \
# 0             2       0.0  106.1400          35.46  2011             2011
# 2             4       0.0   29.6400           8.17  2011             2011
# 3             3       0.5  -26.0550           4.82  2011             2011
# 4             5       0.1   37.7700           4.70  2011             2011
# 5             2       0.1   15.3420           1.80  2011             2011
# ...         ...       ...       ...            ...   ...              ...
# 51285         2       0.2    4.5188           0.89  2014             2014
# 51286         1       0.0    0.4200           0.49  2014             2014
# 51287         3       0.0   12.3600           0.35  2014             2014
# 51288         1       0.0    0.5600           0.20  2014             2014
# 51289         3       0.2   -0.6048           0.17  2014             2014
#
#        order_date_month  order_date_week
# ...

# %%
df2 = df[df.dtypes[(df.dtypes == 'float64') |(df.dtypes=='int64')].index]

# %%
df2
# Out:
#        quantity  discount    profit  shipping_cost  year  order_date_year  \
# 0             2       0.0  106.1400          35.46  2011             2011
# 2             4       0.0   29.6400           8.17  2011             2011
# 3             3       0.5  -26.0550           4.82  2011             2011
# 4             5       0.1   37.7700           4.70  2011             2011
# 5             2       0.1   15.3420           1.80  2011             2011
# ...         ...       ...       ...            ...   ...              ...
# 51285         2       0.2    4.5188           0.89  2014             2014
# 51286         1       0.0    0.4200           0.49  2014             2014
# 51287         3       0.0   12.3600           0.35  2014             2014
# 51288         1       0.0    0.5600           0.20  2014             2014
# 51289         3       0.2   -0.6048           0.17  2014             2014
#
#        order_date_month  order_date_week
# ...

# %%
df2[df2>100]
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.14            NaN  2011             2011
# 2           NaN       NaN     NaN            NaN  2011             2011
# 3           NaN       NaN     NaN            NaN  2011             2011
# 4           NaN       NaN     NaN            NaN  2011             2011
# 5           NaN       NaN     NaN            NaN  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       NaN       NaN     NaN            NaN  2014             2014
# 51286       NaN       NaN     NaN            NaN  2014             2014
# 51287       NaN       NaN     NaN            NaN  2014             2014
# 51288       NaN       NaN     NaN            NaN  2014             2014
# 51289       NaN       NaN     NaN            NaN  2014             2014
#
#        order_date_month  order_date_week
# 0                   NaN              NaN
# ...

# %%
df3 = df2[df2>100]

# %%
df3
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.14            NaN  2011             2011
# 2           NaN       NaN     NaN            NaN  2011             2011
# 3           NaN       NaN     NaN            NaN  2011             2011
# 4           NaN       NaN     NaN            NaN  2011             2011
# 5           NaN       NaN     NaN            NaN  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       NaN       NaN     NaN            NaN  2014             2014
# 51286       NaN       NaN     NaN            NaN  2014             2014
# 51287       NaN       NaN     NaN            NaN  2014             2014
# 51288       NaN       NaN     NaN            NaN  2014             2014
# 51289       NaN       NaN     NaN            NaN  2014             2014
#
#        order_date_month  order_date_week
# 0                   NaN              NaN
# ...

# %%
df3.dropna()
# Out:
# Empty DataFrame
# Columns: [quantity, discount, profit, shipping_cost, year, order_date_year, order_date_month, order_date_week]
# Index: []

# %%
df3.dropna(axis=1)
# Out:
#        year  order_date_year
# 0      2011             2011
# 2      2011             2011
# 3      2011             2011
# 4      2011             2011
# 5      2011             2011
# ...     ...              ...
# 51285  2014             2014
# 51286  2014             2014
# 51287  2014             2014
# 51288  2014             2014
# 51289  2014             2014
#
# [51289 rows x 2 columns]

# %%
df3.dropna(thresh=3)
# Out:
#        quantity  discount   profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.140            NaN  2011             2011
# 7           NaN       NaN  110.412         125.32  2011             2011
# 8           NaN       NaN      NaN         107.10  2011             2011
# 9           NaN       NaN  253.320            NaN  2011             2011
# 12          NaN       NaN  290.430            NaN  2011             2011
# ...         ...       ...      ...            ...   ...              ...
# 51234       NaN       NaN  216.720            NaN  2014             2014
# 51236       NaN       NaN  180.240            NaN  2014             2014
# 51245       NaN       NaN  105.000            NaN  2014             2014
# 51252       NaN       NaN  166.440            NaN  2014             2014
# 51269       NaN       NaN  153.090            NaN  2014             2014
#
#        order_date_month  order_date_week
# 0                   NaN              NaN
# ...

# %%
df3
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.14            NaN  2011             2011
# 2           NaN       NaN     NaN            NaN  2011             2011
# 3           NaN       NaN     NaN            NaN  2011             2011
# 4           NaN       NaN     NaN            NaN  2011             2011
# 5           NaN       NaN     NaN            NaN  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       NaN       NaN     NaN            NaN  2014             2014
# 51286       NaN       NaN     NaN            NaN  2014             2014
# 51287       NaN       NaN     NaN            NaN  2014             2014
# 51288       NaN       NaN     NaN            NaN  2014             2014
# 51289       NaN       NaN     NaN            NaN  2014             2014
#
#        order_date_month  order_date_week
# 0                   NaN              NaN
# ...

# %%
df3.fillna(value=4)
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           4.0       4.0  106.14            4.0  2011             2011
# 2           4.0       4.0    4.00            4.0  2011             2011
# 3           4.0       4.0    4.00            4.0  2011             2011
# 4           4.0       4.0    4.00            4.0  2011             2011
# 5           4.0       4.0    4.00            4.0  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       4.0       4.0    4.00            4.0  2014             2014
# 51286       4.0       4.0    4.00            4.0  2014             2014
# 51287       4.0       4.0    4.00            4.0  2014             2014
# 51288       4.0       4.0    4.00            4.0  2014             2014
# 51289       4.0       4.0    4.00            4.0  2014             2014
#
#        order_date_month  order_date_week
# 0                   4.0              4.0
# ...

# %%
df3.fillna(value=df['profit'].mean())
# Out:
#         quantity   discount      profit  shipping_cost  year  order_date_year  \
# 0      28.641595  28.641595  106.140000      28.641595  2011             2011
# 2      28.641595  28.641595   28.641595      28.641595  2011             2011
# 3      28.641595  28.641595   28.641595      28.641595  2011             2011
# 4      28.641595  28.641595   28.641595      28.641595  2011             2011
# 5      28.641595  28.641595   28.641595      28.641595  2011             2011
# ...          ...        ...         ...            ...   ...              ...
# 51285  28.641595  28.641595   28.641595      28.641595  2014             2014
# 51286  28.641595  28.641595   28.641595      28.641595  2014             2014
# 51287  28.641595  28.641595   28.641595      28.641595  2014             2014
# 51288  28.641595  28.641595   28.641595      28.641595  2014             2014
# 51289  28.641595  28.641595   28.641595      28.641595  2014             2014
#
# ...

# %%
df.groupby('order_date_year')['profit'].mean()
# Out:
# order_date_year
# 2011    27.665308
# 2012    28.043722
# 2013    29.604519
# 2014    28.758540
# Name: profit, dtype: float64

# %%
df.groupby('order_date_year')['discount'].mean()
# Out:
# order_date_year
# 2011    0.148193
# 2012    0.141286
# 2013    0.140265
# 2014    0.143291
# Name: discount, dtype: float64

# %%
df.groupby('order_date_year')['shipping_cost'].mean()
# Out:
# order_date_year
# 2011    27.149201
# 2012    25.861329
# 2013    26.418577
# 2014    26.268197
# Name: shipping_cost, dtype: float64

# %%
df['sales'] = df.sales.str.replace(',','').astype(int)

# %%
df.dtypes
# Out:
# order_id                        object
# order_date                      object
# ship_date                       object
# ship_mode                       object
# customer_name                   object
# segment                         object
# state                           object
# country                         object
# market                          object
# region                          object
# product_id                      object
# category                        object
# sub_category                    object
# product_name                    object
# sales                            int32
# quantity                         int64
# discount                       float64
# profit                         float64
# shipping_cost                  float64
# order_priority                  object
# year                             int64
# converted_order_date    datetime64[ns]
# order_date_year                  int64
# order_date_month                 int64
# ...

# %%
df.groupby('order_date_year')['sales'].mean()
# Out:
# order_date_year
# 2011    251.127153
# 2012    244.252235
# 2013    246.819335
# 2014    245.282129
# Name: sales, dtype: float64

# %%
df.groupby('order_date_year')['quantity'].mean()
# Out:
# order_date_year
# 2011    3.494498
# 2012    3.476647
# 2013    3.488369
# 2014    3.457989
# Name: quantity, dtype: float64

# %%
df.groupby('order_date_year')['quantity'].sum()
# Out:
# order_date_year
# 2011    31440
# 2012    38111
# 2013    48136
# 2014    60622
# Name: quantity, dtype: int64

# %%
df.groupby('order_date_year')['sales'].sum()
# Out:
# order_date_year
# 2011    2259391
# 2012    2677493
# 2013    3405860
# 2014    4300041
# Name: sales, dtype: int32

# %% [raw]
# https://drive.google.com/file/d/1FRnbQqgK6S-mr9StNF5MurSaXhah9uoJ/view?usp=sharing
#
#
# https://drive.google.com/file/d/11rPJXr-9VoeV2Pi0RSfVehw1tbQOAjLI/view?usp=sharing
#
# https://docs.google.com/spreadsheets/d/1z4EWsGxw0YBQ1-51xZDxYNlB3ngJzg4t/edit?usp=sharing&ouid=118282207943964605599&rtpof=true&sd=true
#
#
# https://docs.google.com/spreadsheets/d/1z2n8aeFF5GoohQ3KCZw8bKogezpO9l4k/edit?usp=sharing&ouid=118282207943964605599&rtpof=true&sd=true
#
# 1 .Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave
# 2 .Total working days for each agents
# 3. Total query that you hvae taken
# 4. total Feedback that you have received
# 5. a agent name who have average rating between 3.5 to 4
# 6 . Agent name who have rating lesss then 3.5
# 7 . agent name who have rating more then 4.5
# 8 . how many feedaback agents have received more then 4.5 average
# 9 . average weekly response time for each agent
# 10 . average weekely resolution time for each agents
# 11 . list of all agents name
# 12 . percentage of chat on which they have received a feedback
# 13 . Total contributation hour for each and every agents weekly basis
# 14. total percentage of active hour for a month
#
# sunny.savita@ineuron.ai ,sudhanshu@ineuron.ai
#
# deadline of complition of this task is 12 AM IST today
#
# After that if you will submit your task i wont evaluate it at all , excuses will be given to new
# joiners
