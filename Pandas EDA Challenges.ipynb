# %%
import pandas as pd

# %%
df_agent_login = pd.read_excel('Agent_Login_Report (4).xls')

# %%
df_agent_login
# Out:
#      SL No               Agent       Date   Login Time  Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM   02:04:10
# 1        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM   00:00:17
# 2        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM   00:45:06
# 4        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM   01:08:36
# ..     ...                 ...        ...          ...          ...        ...
# 995    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM   05:58:37
# 996    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM   06:00:43
# 997    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM   05:27:34
# 998    999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM   05:16:38
# 999   1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM  514:08:20
#
# [1000 rows x 6 columns]

# %%
df_agent_performance = pd.read_excel('AgentPerformance (1).xlsx')

# %%
df_agent_performance
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %%
# 1 -Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave

# %%
df_agent_performance.dtypes
# Out:
# SL No                        int64
# Date                        object
# Agent Name                  object
# Total Chats                  int64
# Average Response Time       object
# Average Resolution Time     object
# Average Rating             float64
# Total Feedback               int64
# dtype: object

# %%
### Date is in object so need to convert in datetime format
df_agent_performance['Date'] = pd.to_datetime(df_agent_performance['Date'])

# %%
#### now we get date as in datetime format
df_agent_performance.dtypes
# Out:
# SL No                               int64
# Date                       datetime64[ns]
# Agent Name                         object
# Total Chats                         int64
# Average Response Time              object
# Average Resolution Time            object
# Average Rating                    float64
# Total Feedback                      int64
# dtype: object

# %%
df_agent_performance['working_days'] = df_agent_performance['Date'].dt.dayofweek

# %%
df_agent_performance
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1 2022-07-30        Prerna Singh           11              00:00:38
# 1         2 2022-07-30       Nandani Gupta           11              00:01:15
# 2         3 2022-07-30          Ameya Jain           14              00:00:30
# 3         4 2022-07-30       Mahesh Sarade           14              00:01:04
# 4         5 2022-07-30              Swati            14              00:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156 2022-07-01   Sowmiya Sivakumar            0              00:00:00
# 2156   2157 2022-07-01             Nitin M            0              00:00:00
# 2157   2158 2022-07-01              Vivek             0              00:00:00
# 2158   2159 2022-07-01       Ayushi Mishra            0              00:00:00
# 2159   2160 2022-07-01  Chaitra K Hiremath            0              00:00:00
#
# ...

# %%
present_days = df_agent_performance[df_agent_performance['working_days']<=5]

# %%
present_days
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1 2022-07-30        Prerna Singh           11              00:00:38
# 1         2 2022-07-30       Nandani Gupta           11              00:01:15
# 2         3 2022-07-30          Ameya Jain           14              00:00:30
# 3         4 2022-07-30       Mahesh Sarade           14              00:01:04
# 4         5 2022-07-30              Swati            14              00:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156 2022-07-01   Sowmiya Sivakumar            0              00:00:00
# 2156   2157 2022-07-01             Nitin M            0              00:00:00
# 2157   2158 2022-07-01              Vivek             0              00:00:00
# 2158   2159 2022-07-01       Ayushi Mishra            0              00:00:00
# 2159   2160 2022-07-01  Chaitra K Hiremath            0              00:00:00
#
# ...

# %%
present_days.groupby('working_days')['Average Rating'].mean()
# Out:
# working_days
# 0    1.492465
# 1    1.500243
# 2    1.669931
# 3    1.401285
# 4    1.490917
# 5    1.418556
# Name: Average Rating, dtype: float64

# %%
#2 - Total working days for each agents

# %%
df_agent_performance['working_days'] = df_agent_performance['Date'].dt.dayofweek

# %%
# 3 -Total query that you hvae taken

# %%
df_agent_performance.groupby('Agent Name')['Total Chats'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    277
# Aditya_iot       231
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             44
# Wasim            433
# Zeeshan          542
# Name: Total Chats, Length: 70, dtype: int64

# %%
###4 -total Feedback that you have received

# %%
df_agent_performance.groupby('Agent Name')['Total Feedback'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    153
# Aditya_iot       131
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             20
# Wasim            284
# Zeeshan          335
# Name: Total Feedback, Length: 70, dtype: int64

# %%
#5 -a agent name who have average rating between 3.5 to 4

# %%
df_agent_performance[df_agent_performance['Average Rating'].between(3.5, 4, inclusive = True)
  ]['Agent Name']
# Out:
# 4                    Swati
# 10             Manjunatha A
# 73      Boktiar Ahmed Bappy
# 76            Prateek _iot
# 78            Nandani Gupta
#                ...
# 1941         Jawala Prakash
# 2018          Sanjeev Kumar
# 2021          Aditya Shinde
# 2023       Deepranjan Gupta
# 2097          Sanjeev Kumar
# Name: Agent Name, Length: 114, dtype: object

# %%
#6 - Agent name who have rating lesss then 3.5

# %%
df_agent_performance[df_agent_performance['Average Rating']<3.5]['Agent Name']
# Out:
# 1            Nandani Gupta
# 19        Hitesh Choudhary
# 20              Sanjeevan
# 21                Anirudh
# 22        Shiva Srivastava
#                ...
# 2155     Sowmiya Sivakumar
# 2156               Nitin M
# 2157                Vivek
# 2158         Ayushi Mishra
# 2159    Chaitra K Hiremath
# Name: Agent Name, Length: 1474, dtype: object

# %%
#7 -agent name who have rating more then 4.5

# %%
df_agent_performance[df_agent_performance['Average Rating']>4.5]['Agent Name']
# Out:
# 2               Ameya Jain
# 3            Mahesh Sarade
# 5                  Mukesh
# 6          Saikumarreddy N
# 7            Sanjeev Kumar
#                ...
# 2100        Shubham Sharma
# 2101         Jaydeep Dixit
# 2102    Shivananda Sonwane
# 2103        Khushboo Priya
# 2104       Hrisikesh Neogi
# Name: Agent Name, Length: 307, dtype: object

# %%
#8 -how many feedaback agents have received more then 4.5 average

# %%
df_agent_performance[df_agent_performance['Average Rating']>4.5]['Total Feedback'].count()
# Out:
# 307

# %%
#9 -average weekly response time for each agent

# %%
df_agent_performance.groupby('Average Response Time')['working_days'].mean()
# Out:
# Average Response Time
# 00:00:00    3.15492
# 00:00:04    5.00000
# 00:00:14    2.50000
# 00:00:19    5.00000
# 00:00:21    3.80000
#              ...
# 00:06:19    2.00000
# 00:06:34    2.00000
# 00:06:43    1.00000
# 00:07:00    5.00000
# 00:17:28    2.00000
# Name: working_days, Length: 144, dtype: float64

# %%
#10 -average weekely resolution time for each agents

# %%
df_agent_performance.groupby('Average Resolution Time')['working_days'].mean()
# Out:
# Average Resolution Time
# 00:00:00    3.163251
# 00:00:06    5.000000
# 00:00:42    5.000000
# 00:00:49    5.000000
# 00:00:53    6.000000
#               ...
# 01:21:17    4.000000
# 01:26:09    5.000000
# 01:36:37    3.000000
# 02:45:27    4.000000
# 03:43:07    2.000000
# Name: working_days, Length: 612, dtype: float64

# %%
#11 -list of all agents name

# %%
df_agent_performance['Agent Name']
# Out:
# 0             Prerna Singh
# 1            Nandani Gupta
# 2               Ameya Jain
# 3            Mahesh Sarade
# 4                   Swati
#                ...
# 2155     Sowmiya Sivakumar
# 2156               Nitin M
# 2157                Vivek
# 2158         Ayushi Mishra
# 2159    Chaitra K Hiremath
# Name: Agent Name, Length: 2160, dtype: object

# %%
#12 -percentage of chat on which they have received a feedback

# %%
df_agent_performance['percentage_of_chat'] = (df_agent_performance['Total Chats'] / df_agent_performance['Total Chats'].sum()) * 100

# %%
df_agent_performance
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1 2022-07-30        Prerna Singh           11              00:00:38
# 1         2 2022-07-30       Nandani Gupta           11              00:01:15
# 2         3 2022-07-30          Ameya Jain           14              00:00:30
# 3         4 2022-07-30       Mahesh Sarade           14              00:01:04
# 4         5 2022-07-30              Swati            14              00:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156 2022-07-01   Sowmiya Sivakumar            0              00:00:00
# 2156   2157 2022-07-01             Nitin M            0              00:00:00
# 2157   2158 2022-07-01              Vivek             0              00:00:00
# 2158   2159 2022-07-01       Ayushi Mishra            0              00:00:00
# 2159   2160 2022-07-01  Chaitra K Hiremath            0              00:00:00
#
# ...

# %%
#13 -Total contributation hour for each and every agents weekly basis

# %%
df_agent_login
# Out:
#      SL No               Agent       Date   Login Time  Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM   02:04:10
# 1        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM   00:00:17
# 2        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM   00:45:06
# 4        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM   01:08:36
# ..     ...                 ...        ...          ...          ...        ...
# 995    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM   05:58:37
# 996    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM   06:00:43
# 997    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM   05:27:34
# 998    999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM   05:16:38
# 999   1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM  514:08:20
#
# [1000 rows x 6 columns]

# %%
df = df_agent_login.groupby('Agent')

# %%
df.first()
# Out:
#                         SL No       Date   Login Time  Logout Time   Duration
# Agent
# Aditya Shinde             403  26-Jul-22  08:17:35 PM  08:19:45 PM   00:02:10
# Aditya_iot                 73  29-Jul-22  05:51:57 PM  08:04:03 PM   02:12:05
# Amersh                    217  28-Jul-22  11:49:46 AM  11:52:26 AM   00:02:40
# Ameya Jain                202  28-Jul-22  03:00:47 PM  09:00:31 PM   05:59:44
# Ankitjha                  332  27-Jul-22  01:46:08 PM  03:47:32 PM   02:01:24
# Anurag Tiwari              11  30-Jul-22  01:06:12 PM  01:11:57 PM   00:05:44
# Aravind                   210  28-Jul-22  01:53:02 PM  01:54:11 PM   00:01:09
# Ayushi Mishra              55  29-Jul-22  08:40:28 PM  08:46:50 PM   00:06:21
# Bharath                   132  29-Jul-22  08:55:47 AM  02:59:16 PM   06:03:29
# Boktiar Ahmed Bappy        34  30-Jul-22  02:09:33 AM  02:52:03 AM   00:42:29
# Chaitra K Hiremath         59  29-Jul-22  07:41:48 PM  07:43:58 PM   00:02:10
# ...

# %%
#14 -total percentage of active hour for a month

# %%
df_agent_login.dtypes
# Out:
# SL No           int64
# Agent          object
# Date           object
# Login Time     object
# Logout Time    object
# Duration       object
# dtype: object

# %%
### Date is in object so need to convert in datetime format
df_agent_login['Date'] = pd.to_datetime(df_agent_login['Date'])

# %%
df_agent_login.dtypes
# Out:
# SL No                   int64
# Agent                  object
# Date           datetime64[ns]
# Login Time             object
# Logout Time            object
# Duration               object
# dtype: object

# %%
df_agent_login['days'] = df_agent_login['Date'].dt.day

# %%
df_agent_login
# Out:
#      SL No               Agent       Date   Login Time  Logout Time  \
# 0        1  Shivananda Sonwane 2022-07-30  03:35:29 PM  05:39:39 PM
# 1        2      Khushboo Priya 2022-07-30  03:06:59 PM  03:07:16 PM
# 2        3       Nandani Gupta 2022-07-30  03:04:24 PM  05:31:07 PM
# 3        4     Hrisikesh Neogi 2022-07-30  02:34:29 PM  03:19:35 PM
# 4        5             Mukesh  2022-07-30  02:03:15 PM  03:11:52 PM
# ..     ...                 ...        ...          ...          ...
# 995    996        Manjunatha A 2022-07-20  09:03:51 AM  03:02:28 PM
# 996    997            Bharath  2022-07-20  09:00:49 AM  03:01:32 PM
# 997    998      Khushboo Priya 2022-07-20  08:59:20 AM  02:26:55 PM
# 998    999        Nishtha Jain 2022-07-20  08:43:55 AM  02:00:33 PM
# 999   1000              Tarun  2022-07-01  01:52:47 AM  12:01:07 PM
#
#       Duration  days
# 0     02:04:10    30
# 1     00:00:17    30
# 2     02:26:42    30
# 3     00:45:06    30
# 4     01:08:36    30
# ...

# %%
df_agent_login.dtypes
# Out:
# SL No                   int64
# Agent                  object
# Date           datetime64[ns]
# Login Time             object
# Logout Time            object
# Duration               object
# days                    int64
# dtype: object

# %%
df_agent_login['Duration_days'] = pd.to_timedelta(df_agent_login.Duration)

# %%
df_agent_login
# Out:
#      SL No               Agent       Date   Login Time  Logout Time  \
# 0        1  Shivananda Sonwane 2022-07-30  03:35:29 PM  05:39:39 PM
# 1        2      Khushboo Priya 2022-07-30  03:06:59 PM  03:07:16 PM
# 2        3       Nandani Gupta 2022-07-30  03:04:24 PM  05:31:07 PM
# 3        4     Hrisikesh Neogi 2022-07-30  02:34:29 PM  03:19:35 PM
# 4        5             Mukesh  2022-07-30  02:03:15 PM  03:11:52 PM
# ..     ...                 ...        ...          ...          ...
# 995    996        Manjunatha A 2022-07-20  09:03:51 AM  03:02:28 PM
# 996    997            Bharath  2022-07-20  09:00:49 AM  03:01:32 PM
# 997    998      Khushboo Priya 2022-07-20  08:59:20 AM  02:26:55 PM
# 998    999        Nishtha Jain 2022-07-20  08:43:55 AM  02:00:33 PM
# 999   1000              Tarun  2022-07-01  01:52:47 AM  12:01:07 PM
#
#       Duration  days    Duration_days
# 0     02:04:10    30  0 days 02:04:10
# 1     00:00:17    30  0 days 00:00:17
# ...

# %%
df_agent_login['hours'] = df_agent_login['Duration_days'].dt.components['hours']

# %%
df_agent_login
# Out:
#      SL No               Agent       Date   Login Time  Logout Time  \
# 0        1  Shivananda Sonwane 2022-07-30  03:35:29 PM  05:39:39 PM
# 1        2      Khushboo Priya 2022-07-30  03:06:59 PM  03:07:16 PM
# 2        3       Nandani Gupta 2022-07-30  03:04:24 PM  05:31:07 PM
# 3        4     Hrisikesh Neogi 2022-07-30  02:34:29 PM  03:19:35 PM
# 4        5             Mukesh  2022-07-30  02:03:15 PM  03:11:52 PM
# ..     ...                 ...        ...          ...          ...
# 995    996        Manjunatha A 2022-07-20  09:03:51 AM  03:02:28 PM
# 996    997            Bharath  2022-07-20  09:00:49 AM  03:01:32 PM
# 997    998      Khushboo Priya 2022-07-20  08:59:20 AM  02:26:55 PM
# 998    999        Nishtha Jain 2022-07-20  08:43:55 AM  02:00:33 PM
# 999   1000              Tarun  2022-07-01  01:52:47 AM  12:01:07 PM
#
#       Duration  days    Duration_days  hours
# 0     02:04:10    30  0 days 02:04:10      2
# 1     00:00:17    30  0 days 00:00:17      0
# ...

# %%
df_agent_login['percentage']= (df_agent_login['hours']/df_agent_login['hours'].sum())*100

# %%
df_agent_login
# Out:
#      SL No               Agent       Date   Login Time  Logout Time  \
# 0        1  Shivananda Sonwane 2022-07-30  03:35:29 PM  05:39:39 PM
# 1        2      Khushboo Priya 2022-07-30  03:06:59 PM  03:07:16 PM
# 2        3       Nandani Gupta 2022-07-30  03:04:24 PM  05:31:07 PM
# 3        4     Hrisikesh Neogi 2022-07-30  02:34:29 PM  03:19:35 PM
# 4        5             Mukesh  2022-07-30  02:03:15 PM  03:11:52 PM
# ..     ...                 ...        ...          ...          ...
# 995    996        Manjunatha A 2022-07-20  09:03:51 AM  03:02:28 PM
# 996    997            Bharath  2022-07-20  09:00:49 AM  03:01:32 PM
# 997    998      Khushboo Priya 2022-07-20  08:59:20 AM  02:26:55 PM
# 998    999        Nishtha Jain 2022-07-20  08:43:55 AM  02:00:33 PM
# 999   1000              Tarun  2022-07-01  01:52:47 AM  12:01:07 PM
#
#       Duration  days    Duration_days  hours  percentage
# 0     02:04:10    30  0 days 02:04:10      2    0.145455
# ...
